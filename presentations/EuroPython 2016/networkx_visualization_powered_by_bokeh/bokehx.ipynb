# %% [markdown]
# # NetworkX Visualization Powered by Bokeh
#
# <br>
# ### EuroPython 2016 (2016-07-22)
#
# ###### Björn Meier

# %% [markdown]
# ### Original Objectives:
# * exploring networks for patterns based on properties like node centrality or clustering
# * visualization in a browser
#
# <br>

# %% [markdown]
# ### Original Solution:
# * generate networks and properties
# * RESTful Flask app to provide data
# * D3.js app for browser visualization

# %% [markdown]
# ## Can we solve this easier?

# %% [markdown]
# ### NetworkX + Bokeh
#
# * define the visualization in pure python
# * interact with your network
#     * change views or change showed properties
#     * manipulate the network and get an updated plot
# * possible embedding in a web app

# %% [markdown]
# #### Now, I will show you how it is done ...

# %% [markdown]
# ## Step 0: Example Data

# %% [markdown]
# <img src=europython-2016-logo-white-bg.png width=400 />

# %% [markdown]
# <img src=twitter.png width=200 />

# %% [markdown]
# * tweets during Europython 2016 @europython
# * author will be linked with users mentioned in a tweet

# %% [markdown]
# ## Step 1: Create a Network

# %%
import networkx
from math import sqrt
network = networkx.read_gml('ep2016.gml')

layout = networkx.spring_layout(network,
                                k=1.1/sqrt(network.number_of_nodes()),
                                iterations=100)
# https://en.wikipedia.org/wiki/Force-directed_graph_drawing

# %% [markdown]
# ![elastic network](images/elastic_network.png)
#
# <sub>Image: https://en.wikipedia.org/wiki/Spring_system</sub>

# %% [markdown]
# * Only nice took look at
# * Flattened into 2D
# * Not accurate

# %% [markdown]
# ## The Cornerstone is the ColumnDataSource
#
# | (id)  | x   | y   | node_name | ... |
# |:-----:|:---:|:---:|:---------:|:---:|
# | 0     | 21  | 3   | da_bjoerni| ... |
# | 1     | 14  | 7   | user47    | ... |
# | ...   | ... | ... | ...       | ... |
#
# * column based data class
# * columns must be sequences of data e.g. lists, pandas.DataFrame, ...
# * changes will effect the plot during a rerendering
# * selection information inside a plot

# %%
from bokeh.models import ColumnDataSource

nodes, nodes_coordinates = zip(*sorted(layout.items()))
nodes_xs, nodes_ys = list(zip(*nodes_coordinates))
nodes_source = ColumnDataSource(dict(x=nodes_xs, y=nodes_ys,
                                     name=nodes))

# %% [markdown]
# ## Step 2: Plot a Network

# %%
from bokeh.plotting import show, figure
from bokeh.io import output_notebook
from bokeh.models import HoverTool

hover = HoverTool(tooltips=[('name', '@name'), ('id', '$index')])
plot = figure(plot_width=800, plot_height=400,
              tools=['tap', hover, 'box_zoom', 'reset'])
r_circles = plot.circle('x', 'y', source=nodes_source, size=10,
                        color='blue', level = 'overlay')

# %%
output_notebook(); show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3f2d9f7a-0925-454a-b3c6-4d041d899020">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="01e3770c-7cdf-422a-8887-a8335a2dc260"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01e3770c-7cdf-422a-8887-a8335a2dc260");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01e3770c-7cdf-422a-8887-a8335a2dc260' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b865474b-1be9-401e-b030-7ecba4a5be4b":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["name","x","y"],"data":{"name":["100Commits","1337bullets","1st1","AartGoossens","AbletonDev","AdaTheShow","AergNuor","AishaXBello","Angel_Cruijff","Angelinux3000","ApacheAirflow","BBC","BBCmicrobit","BYAnalytics_en","BayesianHorse","BetabeersVG","BlueYonderTech","BokehPlots","BorsLTD","CAChemEorg","CIBBVA","Cambolc","Charles_JUDITH","CodingGrace","ContinuumIO","CriteoEng","DRMacIver","DaniBot_","DanielDomeneL","DaryaChyzhyk","DasIstHerrKuska","
ii","europython","euskalencounter","evildmp","exaeducation","facebook","facundobatista","fbuontempo","fedeteotini","fergleiser","fintxuarregi","fishnets88","fleioapp","flubdevork","flyingcircusio","fmasanori","freakboy3742","free_control","fuelex","g16n","gaceta_tec","galindale","gdsteam","georgebernhard","getGNU","getbynder","gherranzc","giovannibajo","globalmikem","godlike64","golangweekly","google","grupospri","gwoptics","hackebrot","hanasulc","hawkieowl","helenst","hendorf","hpk42","hundredrooms","hydarscouser","i4ssecurity","iElectric","iamtontann","iferminm","ifosch","ikarantan","i ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %% [markdown]
# # Step 3: Add the edges
#
# ### Prepare the networkX edges

# %%
def get_edges_specs(_network, _layout):
    d = dict(xs=[], ys=[], alphas=[])
    weights = [d['weight'] for u, v, d in _network.edges(data=True)]
    max_weight = max(weights)
    calc_alpha = lambda h: 0.1 + 0.6 * (h / max_weight)

    # example: { ..., ('user47', 'da_bjoerni', {'weight': 3}), ... }
    for u, v, data in _network.edges(data=True):
        d['xs'].append([_layout[u][0], _layout[v][0]])
        d['ys'].append([_layout[u][1], _layout[v][1]])
        d['alphas'].append(calc_alpha(data['weight']))
    return d

# %% [markdown]
# ### Create a ColumnDataSource for the edges

# %%
lines_source = ColumnDataSource(get_edges_specs(network, layout))

# %%
r_lines = plot.multi_line('xs', 'ys', line_width=1.5,
                          alpha='alphas', color='navy',
                          source=lines_source)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6ed1c7a1-119e-4d72-9657-d5d894380eb3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6ed1c7a1-119e-4d72-9657-d5d894380eb3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6ed1c7a1-119e-4d72-9657-d5d894380eb3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"652e6c5c-946c-49cb-80d4-2d945130ba16":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["name","x","y"],"data":{"name":["100Commits","1337bullets","1st1","AartGoossens","AbletonDev","AdaTheShow","AergNuor","AishaXBello","Angel_Cruijff","Angelinux3000","ApacheAirflow","BBC","BBCmicrobit","BYAnalytics_en","BayesianHorse","BetabeersVG","BlueYonderTech","BokehPlots","BorsLTD","CAChemEorg","CIBBVA","Cambolc","Charles_JUDITH","CodingGrace","ContinuumIO","CriteoEng","DRMacIver","DaniBot_","DanielDomeneL","DaryaChyzhyk","DasIstHerrKuska","DavidjMarkey","DeborahTaos12","DigitYasuhara","DjangoGirlsDUB","DjangoGirlsEP16","DjangoGirlsEc","EPfestival","ElnexoMarit","EnCuKou","EnriquetaSo","EntropyFarmer","Eurocentrique","EventGeekie","FAECTA_","FernanMilla","Foxinsock","GMLudo","Garrosa","GinnyGhezzo","GlaciarBlue","Glenio_Oliveira","GrandsCru","GsBitBalear","Gtzl","HashtagLaToya","HelloML9","HokstadConsult","HugoHerter","IKERGUNE","ITCrowdsource","IcanadasM","IldikoVancsa","ImaneElAzlouk","InspirefestHQ","JOANNALETIZIA","JancaStroma","JasmineMcTigue","Jaysinhp","JohaPrime","JoseOpposite","JuliaDrBa","KoehlerKerstin","LIGO","LaetitiaCarquet","LatitudeFest","Limejump","Luen","MBonell","Macario8","MakingLyst","MarcoBasic","MariaDehn","MartaUhlirova","MassHaste","MaxBenChrist","Miau_DB","MiloslavPojman","MirkoDziadzka","MissPhilbin","MongoDB","MrsCaroline_C","N4h_H4N","NaomiCeder","NegoBide","NeuroSky","NotANormalNerd","NowLivecodingtv","OReillyMedia","OpenAtWE","OpenStack","PCalcao","Patjouk","Pazqo","PiusNyongesa","Polyconseiltech","Ppuji1Ppuji","PyCharm_edu","PyConUK","PyLadiesDub","PythonEggs","PythonIreland","PythonSV","RLerallut","RTFMCelia","RealPython","RedHatNews","Rhapsody_Girl","Rico858","SEReuskadi","STajbakhsh","SalamancaPeral","SaltStack","SaltStackInc","SancasDev","Sesivany","Sophie_Talent","Spanarchie","SparkyCZ","SrNilsson","StefanTuralski","StephLKim","Sustatu","TFConsult","TeX4Publication","ThePSF","ThomasJWaldmann","Transition","Twitteze","Ukerzel","VictorStinner","Vince92100","ViniciusPach","WickFelix","WillingCarol","WillyFrog_","WuShell","_JamesRG","__amol__","__katatonia","__pamaron__","_joac","aRkadeFR","a_soldatenko","abelgvidal","aborttrap6","achimdomma","acollard","acpyss","adambcn","aitzol","ajolo","alabarga","alba_caon","alepernin","alex_savio","alison985","almu_hs","aloctavodia","amleczko","andrew_svetlov","angineering","angvp","aniawsz","aniiimaginary","apueblago","argenpython","argonemyth","asendecka","asereteresa23","astrojuanlu","avillamarink","b1n0anb","b_smoke","barakamediatv","bayerdi","bazkennedy","bbc_microbit","bbva","ben_nuttall","bilbaochess","blckdt","bmispelon","bobcatwilson","boiagames","calvinhp","carlosperate","carohadad","ccdesales","cemnova","ch_doig","christianbarra","clinker","coala_analyzer","cobe","cobeio","codekee","codesyntax","codingquark","colmharrington","connctBunker","cool_python","cris_calvo","ctrebing","d0ugal","dArignac","da_bjoerni","dajoffe","daniel7773121","data_hope","dbra","deblike","deshipu","devbootcamp","dfflanders","diegor","djangocon","djangogirls","docker","doriczapari","doughellmann","douglasandrade","drgarcia1986","drridolfo","drvinceknight","dynamitts","dzen","eastigarraga","echorand","edu2b","eitbAlbisteak","eitbNoticias","eladyonas","eliasmoli","eliasthorpet","elmundoempresa","emergya","eolo999","er1p","erralin","esletweets","euro_ii","europython","euskalencounter","evildmp","exaeducation","facebook","facundobatista","fbuontempo","fedeteotini","fergleiser","fintxuarregi","fishnets88","fleioapp","flubdevork","flyingcircusio","fmasanori","freakboy3742","free_control","fuelex","g16n","gaceta_tec","galindale","gdsteam","georgebernhard","getGNU","getbynder","gherranzc","giovannibajo","globalmikem","godlike64","golangweekly","google","grupospri","gwoptics","hackebrot","hanasulc","hawkieowl","helenst","hendorf","hpk42","hundredrooms","hydarscouser","i4ssecurity","iElectric","iamtontann","iferminm","ifosch","ikarantan","i ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %% [markdown]
# # Step 4: Visualize properties
#
# ### Add Clustering and Centrality to ColumnDataSource

# %%
centrality =\
    networkx.algorithms.centrality.betweenness_centrality(network)
# first element are nodes again
_, nodes_centrality = zip(*sorted(centrality.items()))
max_centraliy = max(nodes_centrality)
nodes_source.add([7 + 10 * t / max_centraliy
                  for t in nodes_centrality],
                 'centrality')
# Out:
# 'centrality'

# %%
import community # python-louvain
partition = community.best_partition(network)
p_, nodes_community = zip(*sorted(partition.items()))
nodes_source.add(nodes_community, 'community')
community_colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628', '#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761
,7.0,7.0,7.0,7.0001833723896025,7.0,7.0,7.0,7.000479322869634,7.0,7.0,7.0,7.0,7.0,7.0,7.006070974387609,7.045409671752413,7.0,7.0,7.0,7.0,7.022654825224497,7.0036340326997735,7.0,7.020601243547817,7.006645034374414,7.0036340326997735,7.043181699595062,7.0,7.0,7.001350287596162,7.014119201980407,7.0,7.0036340326997735,7.0,7.0,7.000700149123936,7.0,7.00005001065171,7.045409671752413,7.021041472940489,7.00005001065171,7.090719322201407,7.0,7.000075015977565,7.0,7.090719322201407,7.0036340326997735,7.0,7.0,7.0,7.006384058145711,7.0,7.0,7.0,7.0036340326997735,7.007730937409915,7.000562619831734,7.014059633015827,7.0,7.006070974387609,7.0,7.022654825224497,7.0,7.0,7.00005001065171,7.0036340326997735,7.0,7.0,7.0,7.0,7.000100021303419,7.0,7.0,7.00005001065171,7.0,7.000771354766132,7.0,7.001400298247872,7.001169557571996,7.246365619056506,7.0,7.0,7.0,7.0,7.0147012307079235,7.0,7.0,7.0,7.031932767562132,7.0,7.0,7.000908838261034,7.0,7.0,7.0,7.000306176323245,7.0,7.0,7.0,7.022654825224497,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.000033340434473,7.0,7.0225881443555505,7.0,7.014059633015827,7.0,7.006070974387609,7.0,7.0,7.182322772106069,7.038081470677081,7.0,7.045409671752413,7.0,7.0,7.000965810102358,7.0,7.0,7.090719322201407,7.0,7.0,7.007975058347838,7.0,7.0,7.0,7.0,7.0,7.0,7.000250053258548,7.0,7.000666808689463,7.0,7. ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %% [markdown]
# # Step 5: Interactions

# %% [markdown]
# ### Get Selected Nodes
#
# `ColumnDataSource.selected`
# ```python
# {
#  # line or patch glyph selections
#  '0d': {'get_view': {}, 'glyph': None,
#         'indices': []},
#  # all other glyph selections
#  '1d': {'indices': [73]},
#  # [multi]line or patch selections
#  '2d': {'indices': []}
# }
# ```

# %% [markdown]
# ### Remove Node

# %%
def remove_node():
    idx = nodes_source.selected['1d']['indices'][0]
    
    # update networkX network
    node = nodes_source.data['name'][idx]
    network.remove_node(node)
    
    # update layout
    layout.pop(node)
    
    # update nodes ColumnDataSource
    new_source_data = dict()
    for column in nodes_source.column_names:
        new_source_data[column] =\
        [e for i, e in enumerate(nodes_source.data[column])
         if i != idx]
    nodes_source.data = new_source_data

    # update lines ColumnDataSource
    lines_source.data = get_edges_specs(network, layout)

# %% [markdown]
# ### Notebook Limitations
# * no direct redraw after changing the ColumnDataSource
# * getting selected nodes is not working
# * can not run arbitrary python code started by widges, e.g. buttons
#
# <br>
#
# ### Bokeh Server
# ```
# bokeh serve your_app.py
# ```
#
# [http://localhost:5006/bokehx_app](http://localhost:5006/bokehx_app)

# %% [markdown]
# # Thank You
#
# The slides and code can be found at:
#
# [https://github.com/blue-yonder/documents](https://github.com/blue-yonder/documents)
#
# <br>
# ## NetworkX
# [https://networkx.github.io](https://networkx.github.io)
#
# <br>
# ## Bokeh
# [http://bokeh.pydata.org](http://bokeh.pydata.org)
